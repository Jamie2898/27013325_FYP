# %%
import matplotlib.pyplot as plt

# %%
# ===================================
# Baseline
# Male Binary Classification
# ===================================


x1=['SVM','LR','DT','RF']
y1=[69,76,85,73]
x2=['SVM','LR','DT','RF']
y2=[81,85,83,90]
x3=['SVM','LR','DT','RF']
y3=[69,69,67,77]
plt.figure(figsize=(9.6, 7.2))
l1=plt.plot(x1,y1,'r--',label='CN-MCI')
l2=plt.plot(x2,y2,'g--',label='CN-AD')
l3=plt.plot(x3,y3,'b--',label='MCI-AD')
plt.plot(x1,y1,'ro-',x2,y2,'g+-',x3,y3,'b^-')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Baseline - Male Binary Classification', fontsize=15)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(loc=2, prop={'size': 15})
plt.show()

# %%
# ===================================
# Female Binary Classification
# Baseline
# ===================================


x1=['SVM','LR','DT','RF']
y1=[82,83,68,86]
x2=['SVM','LR','DT','RF']
y2=[83,88,81,86]
x3=['SVM','LR','DT','RF']
y3=[68,56,68,74]
plt.figure(figsize=(9.6, 7.2))
l1=plt.plot(x1,y1,'r--',label='CN-MCI')
l2=plt.plot(x2,y2,'g--',label='CN-AD')
l3=plt.plot(x3,y3,'b--',label='MCI-AD')
plt.plot(x1,y1,'ro-',x2,y2,'g+-',x3,y3,'b^-')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Baseline - Female Binary Classification', fontsize=15)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(loc=3, prop={'size': 15})
plt.show()

# %%
# ===================================
# Male Binary Classification
# ===================================


x1=['SVM','LR','DT','RF']
y1=[84,84,89,76]
x2=['SVM','LR','DT','RF']
y2=[92,92,88,94]
x3=['SVM','LR','DT','RF']
y3=[79,82,85,79]
plt.figure(figsize=(9.6, 7.2))
l1=plt.plot(x1,y1,'r--',label='CN-MCI')
l2=plt.plot(x2,y2,'g--',label='CN-AD')
l3=plt.plot(x3,y3,'b--',label='MCI-AD')
plt.plot(x1,y1,'ro-',x2,y2,'g+-',x3,y3,'b^-')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Male Binary Classification', fontsize=15)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(loc=3, prop={'size': 15})
plt.show()

# %%
# ===================================
# Female Binary Classification
# ===================================


x1=['SVM','LR','DT','RF']
y1=[85,82,78,86]
x2=['SVM','LR','DT','RF']
y2=[95,93,86,88]
x3=['SVM','LR','DT','RF']
y3=[82,76,74,82]
plt.figure(figsize=(9.6, 7.2))
l1=plt.plot(x1,y1,'r--',label='CN-MCI')
l2=plt.plot(x2,y2,'g--',label='CN-AD')
l3=plt.plot(x3,y3,'b--',label='MCI-AD')
plt.plot(x1,y1,'ro-',x2,y2,'g+-',x3,y3,'b^-')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Female Binary Classification', fontsize=15)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(loc=3, prop={'size': 15})
plt.show()

# %%
# =========================================
# Multi-classification
# All gender - Baseline
# =========================================


x1=['SVM','LR','DT','RF']
y1=[52,52,48,65]
x2=['SVM','LR','DT','RF']
y2=[59,56,53,71]
plt.figure(figsize=(9.6, 7.2))
l1=plt.plot(x1,y1,'r--',label='Male')
l2=plt.plot(x2,y2,'g--',label='Female')
plt.plot(x1,y1,'ro-',x2,y2,'g+-')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Multi-classification baseline', fontsize=15)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(loc=3, prop={'size': 15})
plt.show()

# %%
# =========================================
# Multi-classification
# =========================================


x1=['SVM','LR','DT','RF']
y1=[65,61,61,68]
x2=['SVM','LR','DT','RF']
y2=[73,67,51,79]
plt.figure(figsize=(9.6, 7.2))
l1=plt.plot(x1,y1,'r--',label='Male')
l2=plt.plot(x2,y2,'g--',label='Female')
plt.plot(x1,y1,'ro-',x2,y2,'g+-')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Multi-classification', fontsize=15)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(loc=3, prop={'size': 15})
plt.show()
